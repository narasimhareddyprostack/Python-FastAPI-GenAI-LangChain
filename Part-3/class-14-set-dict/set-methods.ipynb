# %%
#differernce b/ set.remove() vs set.discard()
enames={"RG","SG","PG"}
enames.discard("Modi")
print(enames)
# Out:
# {'SG', 'RG', 'PG'}

# %%
#differernce b/ set.remove() vs set.discard()
enames={"RG","SG","PG"}
enames.remove("Modi")
print(enames)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[2], line 3
#       1 #differernce b/ set.remove() vs set.discard()
#       2 enames={"RG","SG","PG"}
# ----> 3 enames.remove("Modi")
#       4 print(enames)
#
# KeyError: 'Modi'

# %%
def login(name,status):
    pass 

login()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 4
#       1 def login(name,status):
#       2     pass
# ----> 4 login()
#
# TypeError: login() missing 2 required positional arguments: 'name' and 'status'
